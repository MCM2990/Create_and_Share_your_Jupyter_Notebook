# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In diesem Notebook werden die Werkzeuge und Ökosysteme der Datenwissenschaft zusammengefasst

# %% [markdown]
# ## Ziele
#
# In diesem Notebook werden einige der wichtigsten Erkenntnisse aus dem Kurs zusammengefasst.
#
# - Kennenlernen beliebter Programmiersprachen für Data Science
# - verständnis von Data Science Tools und -ökosystemen
# - einführung in verschiedene Entwicklungsumgebungen
# - einführung in die verschiedenen Libraries für Data Science

# %% [markdown]
# Einige der belibtesten Sprachen, die Datenwissenschaftler verwenden, sind:
# 1. Python
# 2. R
# 3. SQL
# 4. Julia
# 5. C++

# %% [markdown]
# Einige der häufig verwendeten Bibliotheken, die von Datenwissenschaftlern verwendet werden, sind:
# 1. Pandas
# 2. matplotlib
# 3. numpy
# 4. ggplot2
# 5. Tensorflow

# %% [markdown]
# | Data Science Tools |
# | ------------------ |
# | Jupyter Notebook |
# | RStudio |
# | Spyder |

# %% [markdown]
# ### Unten sind einige Beispiele zur Auswertung arithmetischer Ausdrücke in Python.

# %%
(3*4)+5
# Dies ist ein einfacher arithmetischer Ausdruck, um Ganzzahlen zu multiplizieren und dann zu addieren
# Out:
# 17

# %%
200/60
#Dies wandelt 200 Minuten in Stunden um, indem durch 60 geteilt wird
# Out:
# 3.3333333333333335

# %% [markdown]
# ## Autor
# Michael-Andreas Ksiezarczyk
